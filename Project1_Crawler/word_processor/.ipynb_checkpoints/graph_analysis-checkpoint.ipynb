# %%
# Purpose: Apply Zipf's Law and Heap's Law to web crawled data
# Accepts English, Spanish, and lastly Farsi(non-latin script)

import processor as wp
import pandas as pd
import matplotlib.pyplot as plt

english = wp.process_text("english", "../repository/English/")
spanish = wp.process_text("spanish", "../repository/Spanish/")
farsi = wp.process_text("farsi", "../repository/Farsi/")

# %%
print(sum(english.values()))
# Out:
# 334631

# %% [markdown]
# # English

# %%
df_en = pd.DataFrame(english.most_common(50),
                         columns = ['words', 'count'])
df_en.drop([0], inplace=True)
df_en.head(50)
# Out:
#          words  count
# 1       states   4122
# 2       united   3847
# 3         date   3486
# 4         cite   2986
# 5        title   2974
# 6     template   2151
# 7          web   2050
# 8       access   1916
# 9    publisher   1830
# 10        view   1544
# 11   protected   1539
# 12      source   1530
# 13    american   1438
# 14     archive   1322
# 15       books   1320
# 16       first   1233
# 17      editor   1175
# 18        isbn   1169
# 19       world   1050
# 20        year   1025
# 21        book   1008
# 22        name    927
# 23        page    924
# 24        last    877
# 25     america    815
# 26         war    788
# 27          id    773
# 28         new    772
# 29     history    771
# 30         gov    735
# 31     country    725
# 32     website    695
# 33          us    650
# 34      google    626
# 35    language    592
# 36         pdf    584
# 37        news    575
# 38       press    568
# 39          pg    530
# 40      author    521
# 41   americans    520
# 42     january    509
# 43       state    504
# 44        html    500
# 45     october    499
# 46      module    495
# 47     federal    480
# 48        data    441
# 49  university    432

# %%
fig, ax = plt.subplots(figsize=(15, 15))
df_en.sort_values(by='count').plot.barh(x='words',
                                                y='count',
                                                ax=ax,
                                                color="blue")
ax.set_title("English Common Crawled Words")
plt.show()

# %% [markdown]
# # Spanish

# %%
df_sp = pd.DataFrame(english.most_common(50),
                         columns = ['words', 'count'])
df_sp.drop([0], inplace=True)
df_sp.head(50)
# Out:
#          words  count
# 1       states   4122
# 2       united   3847
# 3         date   3486
# 4         cite   2986
# 5        title   2974
# 6     template   2151
# 7          web   2050
# 8       access   1916
# 9    publisher   1830
# 10        view   1544
# 11   protected   1539
# 12      source   1530
# 13    american   1438
# 14     archive   1322
# 15       books   1320
# 16       first   1233
# 17      editor   1175
# 18        isbn   1169
# 19       world   1050
# 20        year   1025
# 21        book   1008
# 22        name    927
# 23        page    924
# 24        last    877
# 25     america    815
# 26         war    788
# 27          id    773
# 28         new    772
# 29     history    771
# 30         gov    735
# 31     country    725
# 32     website    695
# 33          us    650
# 34      google    626
# 35    language    592
# 36         pdf    584
# 37        news    575
# 38       press    568
# 39          pg    530
# 40      author    521
# 41   americans    520
# 42     january    509
# 43       state    504
# 44        html    500
# 45     october    499
# 46      module    495
# 47     federal    480
# 48        data    441
# 49  university    432

# %%
fig, ax = plt.subplots(figsize=(15, 15))
df_sp.sort_values(by='count').plot.barh(x='words',
                                                y='count',
                                                ax=ax,
                                                color="blue")
ax.set_title("Spanish Common Crawled Words")
plt.show()

# %% [markdown]
# # Farsi

# %%
df_farsi = pd.DataFrame(english.most_common(50),
                         columns = ['words', 'count'])
df_farsi.drop([0], inplace=True)
df_farsi.head(50)
# Out:
#          words  count
# 1       states   4122
# 2       united   3847
# 3         date   3486
# 4         cite   2986
# 5        title   2974
# 6     template   2151
# 7          web   2050
# 8       access   1916
# 9    publisher   1830
# 10        view   1544
# 11   protected   1539
# 12      source   1530
# 13    american   1438
# 14     archive   1322
# 15       books   1320
# 16       first   1233
# 17      editor   1175
# 18        isbn   1169
# 19       world   1050
# 20        year   1025
# 21        book   1008
# 22        name    927
# 23        page    924
# 24        last    877
# 25     america    815
# 26         war    788
# 27          id    773
# 28         new    772
# 29     history    771
# 30         gov    735
# 31     country    725
# 32     website    695
# 33          us    650
# 34      google    626
# 35    language    592
# 36         pdf    584
# 37        news    575
# 38       press    568
# 39          pg    530
# 40      author    521
# 41   americans    520
# 42     january    509
# 43       state    504
# 44        html    500
# 45     october    499
# 46      module    495
# 47     federal    480
# 48        data    441
# 49  university    432

# %%
fig, ax = plt.subplots(figsize=(15, 15))
df_farsi.sort_values(by='count').plot.barh(x='words',
                                                y='count',
                                                ax=ax,
                                                color="blue")
ax.set_title("Farsi Common Crawled Words")
plt.show()
