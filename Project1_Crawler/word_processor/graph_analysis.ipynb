# %%
# Purpose: Apply Zipf's Law and Heap's Law to web crawled data
# Accepts English, Spanish, and lastly Farsi(non-latin script)

import processor as wp
import pandas as pd
import matplotlib.pyplot as plt

english = wp.process_text("english", "../repository/English/")
spanish = wp.process_text("spanish", "../repository/Spanish/")
farsi = wp.process_text("farsi", "../repository/Farsi/")

# %% [markdown]
# # English

# %%
df_en = pd.DataFrame(english.most_common(25),
                         columns = ['words', 'count'])
df_en.drop([0], inplace=True)
df_en.head(10)
# Out:
#        words  count
# 1     states   4122
# 2     united   3847
# 3       date   3486
# 4        url   3321
# 5       cite   2986
# 6      title   2974
# 7      https   2424
# 8   template   2151
# 9        web   2050
# 10    access   1916

# %%
fig, ax = plt.subplots(figsize=(15, 15))
df_en.sort_values(by='count').plot.barh(x='words',
                                                y='count',
                                                ax=ax,
                                                color="blue")
ax.set_title("English Common Crawled Words")
plt.show()

# %% [markdown]
# # Spanish

# %%
df_sp = pd.DataFrame(english.most_common(25),
                         columns = ['words', 'count'])
df_sp.drop([0], inplace=True)
df_sp.head(10)
# Out:
#        words  count
# 1     states   4122
# 2     united   3847
# 3       date   3486
# 4        url   3321
# 5       cite   2986
# 6      title   2974
# 7      https   2424
# 8   template   2151
# 9        web   2050
# 10    access   1916

# %% [markdown]
# # Farsi

# %%
df_farsi = pd.DataFrame(english.most_common(25),
                         columns = ['words', 'count'])
df_farsi.drop([0], inplace=True)
df_farsi.head(10)
# Out:
#        words  count
# 1     states   4122
# 2     united   3847
# 3       date   3486
# 4        url   3321
# 5       cite   2986
# 6      title   2974
# 7      https   2424
# 8   template   2151
# 9        web   2050
# 10    access   1916
